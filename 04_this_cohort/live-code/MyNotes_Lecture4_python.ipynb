# %% [markdown]
# Using a function vs method
#
# here we have lists
#
# .extend()
#
# .append()
#
# .clear()

# %%
lunch = ['sandwich','soup','salad']

# %%
lunch
# Out:
# ['sandwich', 'soup', 'salad']

# %%
lunch[0]
# Out:
# 'sandwich'

# %%
fruits = ['pineapple','apple','kiwi','banana']
fruits
# Out:
# ['pineapple', 'apple', 'kiwi', 'banana']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'banana', 'kiwi', 'pineapple']

# %%
veggies = ['potatoes','celery','cabbage','bell pepper', 'onion']

# %%
sorted(veggies)
# Out:
# ['bell pepper', 'cabbage', 'celery', 'onion', 'potatoes']

# %%
veggies
# Out:
# ['potatoes', 'celery', 'cabbage', 'bell pepper', 'onion']

# %% [markdown]
# sorted() func does not change the list itself as it is a function
#
#
# listname.sort() method changes it permanently as it is a method

# %%
list_example2 = ['Banana','apple','Apple']
list_example2
# Out:
# ['Banana', 'apple', 'Apple']

# %%
sorted(list_example2)
# Out:
# ['Apple', 'Banana', 'apple']

# %% [markdown]
# # sorted() sorts based on the unicode value
#
# A - 65
#
#
# a - 97

# %%
veggies = ['potato','celery','cabbage','bell pepper','onion']

# %%
sorted(veggies)
# Out:
# ['bell pepper', 'cabbage', 'celery', 'onion', 'potato']

# %%
def last_letter(text):
    return text[-1]

# %%
sorted(veggies,key=last_letter)
# Out:
# ['cabbage', 'onion', 'potato', 'bell pepper', 'celery']

# %%
students_per_class = [['Grade 9',20],['Grade 10',17],['Grade 11',13],['Grade',22]]

# %%
def second_element(item):
    return item[1]

#we are taking the second element of the list and return that (index=1)

# %%
students_per_class.sort(key=second_element)

# %%
students_per_class
# Out:
# [['Grade 11', 13], ['Grade 10', 17], ['Grade 9', 20], ['Grade', 22]]

# %% [markdown]
# we put the function as a key in the method

# %% [markdown]
# # Tuples
#
# ()

# %%
mutable_synonyms = ('changable','fluctuating','inconstant','variable')

# %%
empty_tuple1 = ()
type(empty_tuple1)
# Out:
# tuple

# %% [markdown]
# tuples are inmutable
#
# once they are created, they are not changeable. no append.. nothing

# %%
empty_tuple2 = ()
type(empty_tuple2)
# Out:
# tuple

# %%
empty_tuple1.append('hi')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 empty_tuple1.append('hi')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
len(mutable_synonyms)
# Out:
# 4

# %%
mutable_synonyms.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 mutable_synonyms.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %% [markdown]
# # Set
#
# {}

# %%
things = {'coat','lock','box','book','apple','hair','xylophone','lock','book'}

# %%
things
# Out:
# {'apple', 'book', 'box', 'coat', 'hair', 'lock', 'xylophone'}

# %% [markdown]
# all the duplicates are shown once
# every single item will be unique
# set datatype is in order
#
# it has its own algorithm, not alphabetical actually. has its own algorithm

# %%
type(things)
# Out:
# set

# %%
visitor_post_codes = ['M5R','M5V','M1M','M1M','M1T']

# %%
set(visitor_post_codes) #we changed the datatype to set, and it got ordered and duplicates are removed
# Out:
# {'M1M', 'M1T', 'M5R', 'M5V'}

# %%
things
# Out:
# {'apple', 'book', 'box', 'coat', 'hair', 'lock', 'xylophone'}

# %%
things.add('lock')
things
# Out:
# {'apple', 'book', 'box', 'coat', 'hair', 'lock', 'xylophone'}

# %%
things.remove('apple')

# %%
things
# Out:
# {'book', 'box', 'coat', 'hair', 'lock', 'xylophone'}

# %%
things[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 things[1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# since the set is not in order, we cannot access the elements with their index

# %%
rainbow = {'red','orange','yellow','green','blue','indigo','violet'}

# %%
olympic_flag = {'red','green','yellow','blue','black'}

# %%
rainbow.difference(olympic_flag) #order matter. we have these values in first, not in the second set
# Out:
# {'indigo', 'orange', 'violet'}

# %%
olympic_flag.difference(rainbow)
# Out:
# {'black'}

# %%
#symmetric difference find the values that are in only one of two sets

rainbow.symmetric_difference(olympic_flag)
# Out:
# {'black', 'indigo', 'orange', 'violet'}

# %%
rainbow.intersection(olympic_flag) #intersection -  finds the values two sets in common
# Out:
# {'blue', 'green', 'red', 'yellow'}

# %%
#union combine two sets to get the unique values in both

rainbow.union(olympic_flag)
# Out:
# {'black', 'blue', 'green', 'indigo', 'orange', 'red', 'violet', 'yellow'}

# %% [markdown]
# # Dictionary
#
#
# key: value  - like a pair
#
# dictionaries are ordered and mutable
#
#
# every key is unique, keys can be any immutable data types
#
#
# values can be any data type

# %%
capitals = {'Canada':'Ottawa',
            'Mexico': 'Mexico City'}

# %%
type(capitals)
# Out:
# dict

# %%
olympic_cities = {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London'}
olympic_cities
# Out:
# {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London'}

# %%
all_olympic_hosts = {'summer': olympic_cities,
                     'winter': {2022: 'Beijing', 2018: 'Pyeongchang'}}
all_olympic_hosts
# Out:
# {'summer': {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London'},
#  'winter': {2022: 'Beijing', 2018: 'Pyeongchang'}}

# %% [markdown]
# set is not mutable
#
# dictionaries are mutable

# %%
olympic_cities[2020]
# Out:
# 'Tokyo'

# %%
olympic_cities[2012]
# Out:
# 'London'

# %%
all_olympic_hosts
# Out:
# {'summer': {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London'},
#  'winter': {2022: 'Beijing', 2018: 'Pyeongchang'}}

# %%
all_olympic_hosts['summer']
# Out:
# {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London'}

# %% [markdown]
# key winter - correspoding values are ... dictionary

# %%
all_olympic_hosts['winter']
# Out:
# {2022: 'Beijing', 2018: 'Pyeongchang'}

# %%
all_olympic_hosts['winter'][2022] #in key winter that gives the dictionary, the key 2022 corresponds to the dictonary beijing
# Out:
# 'Beijing'

# %%
olympic_cities
# Out:
# {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London'}

# %%
olympic_cities.get(2004,'Athens') #if it doesnt find 2004, it returns the default value 'Athens'
# Out:
# 'Athens'

# %%
olympic_cities.get(2004)

# %%
olympic_cities[2004]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 olympic_cities[2004]
#
# KeyError: 2004

# %%
olympic_cities[2008] = 'Beijing'

# %%
olympic_cities
# Out:
# {2020: 'Tokyo', 2016: 'Rio de Janiero', 2012: 'London', 2008: 'Beijing'}

# %%
del olympic_cities[2020] #deletes object
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 del olympic_cities[2020] #deletes object
#       3 olympic_cities
#
# KeyError: 2020

# %%
olympic_cities
# Out:
# {2016: 'Rio de Janiero', 2012: 'London', 2008: 'Beijing'}

# %% [markdown]
# key : value

# %%
all_olympic_hosts.keys()
# Out:
# dict_keys(['summer', 'winter'])

# %% [markdown]
# # Concept maps
#
# data types, if they are mutable or unmutable, ordered or not ordered

# %%
all_olympic_hosts.values()
# Out:
# dict_values([{2016: 'Rio de Janiero', 2012: 'London', 2008: 'Beijing'}, {2022: 'Beijing', 2018: 'Pyeongchang'}])

# %%
all_olympic_hosts.items()
# Out:
# dict_items([('summer', {2016: 'Rio de Janiero', 2012: 'London', 2008: 'Beijing'}), ('winter', {2022: 'Beijing', 2018: 'Pyeongchang'})])

# %% [markdown]
# how to tell python how to repeat chunks of code

# %%
# for loop
# run an indented block of code for every item in an iterable

for i in ['monday','tuesday','wednesday','thursday']: 
    print(i)
# Out:
# monday
# tuesday
# wednesday
# thursday

# %%
for number in {1, 2, 3, 4, 5}: #number = .. assigned to each and gets printed
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
items = {'cat','apple','dog'}

# %%
for item in items:
    print(item)
# Out:
# apple
# dog
# cat

# %%
for i in range(7):
    print(i, i*2)
# Out:
# 0 0
# 1 2
# 2 4
# 3 6
# 4 8
# 5 10
# 6 12

# %%
for i in range(2,6): #start at 2, up to but not including 6
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
input_files = ['data_01.csv', 'data_02.csv', 'data_03.csv']
output_files = []

for i in input_files:
    output_file_name = i.replace('.csv','.xlsx') #output_file_name = 'data_01.xlsx'
    output_files.append(output_file_name) # output_files = ['data_01.xlsx']

output_files
# Out:
# ['data_01.xlsx', 'data_02.xlsx', 'data_03.xlsx']

# %%
for idx, food in enumerate(['sandwich','veggies','fruit']): #idx = 1. food = 'veggies'
    print (idx, food)
# Out:
# 0 sandwich
# 1 veggies
# 2 fruit

# %% [markdown]
# # Enumerate function
#
# returns back both the index and position, and assigns back to idx
#
# and returns back to position and the item itself
